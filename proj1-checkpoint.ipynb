# %%
# %pip install pyforest
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import pyforest # pyforest meansinbuilt of all the moduls like numpy, pandas,matplotlib, seaborn

# %%
data = pd.read_csv('train.csv')
data
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
data.shape #checking how many rows and columns
# Out:
# (891, 12)

# %%
data.isna().sum() # checking how many null values in the data
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
data.describe() #describing the all data of the coloumns
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
data.dtypes
# Out:
# PassengerId      int64
# Survived         int64
# Pclass           int64
# Name            object
# Sex             object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object

# %% [raw]
# label encoder
# helps to convert the object in to numarical like converting the sex(male, femal in to 0,1 as a cetagorical data)

# %%
#implement label encoder
from sklearn import preprocessing

#label_encoder object knows how to understand word labels.
label_encoder = preprocessing.LabelEncoder()

#encoding label in thecolumn gender
data['Sex']= label_encoder.fit_transform(data['Sex'])
data['Sex'].value_counts() #converting male as 1 and female as 0
# Out:
# Sex
# 1    577
# 0    314
# Name: count, dtype: int64

# %%
data
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name  Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    1  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...    0  38.0      1
# 2                               Heikkinen, Miss. Laina    0  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)    0  35.0      1
# 4                             Allen, Mr. William Henry    1  35.0      0
# ..                                                 ...  ...   ...    ...
# ...

# %%
data = data.drop(['Ticket','Cabin','Name'],axis=1)
data
#droping the unwanted columns with the help of drop() axis= 1 means coloumns
# Out:
#      PassengerId  Survived  Pclass  Sex   Age  SibSp  Parch     Fare Embarked
# 0              1         0       3    1  22.0      1      0   7.2500        S
# 1              2         1       1    0  38.0      1      0  71.2833        C
# 2              3         1       3    0  26.0      0      0   7.9250        S
# 3              4         1       1    0  35.0      1      0  53.1000        S
# 4              5         0       3    1  35.0      0      0   8.0500        S
# ..           ...       ...     ...  ...   ...    ...    ...      ...      ...
# 886          887         0       2    1  27.0      0      0  13.0000        S
# 887          888         1       1    0  19.0      0      0  30.0000        S
# 888          889         0       3    0   NaN      1      2  23.4500        S
# 889          890         1       1    1  26.0      0      0  30.0000        C
# 890          891         0       3    1  32.0      0      0   7.7500        Q
#
# [891 rows x 9 columns]

# %%
data['Age'].median() #finding the mediam values for the age
# Out:
# np.float64(28.0)

# %%
data['Age']=data['Age'].fillna(value=28)
#with the help of fillna i filled the age with the median values for the null values 
data
# Out:
#      PassengerId  Survived  Pclass  Sex   Age  SibSp  Parch     Fare Embarked
# 0              1         0       3    1  22.0      1      0   7.2500        S
# 1              2         1       1    0  38.0      1      0  71.2833        C
# 2              3         1       3    0  26.0      0      0   7.9250        S
# 3              4         1       1    0  35.0      1      0  53.1000        S
# 4              5         0       3    1  35.0      0      0   8.0500        S
# ..           ...       ...     ...  ...   ...    ...    ...      ...      ...
# 886          887         0       2    1  27.0      0      0  13.0000        S
# 887          888         1       1    0  19.0      0      0  30.0000        S
# 888          889         0       3    0  28.0      1      2  23.4500        S
# 889          890         1       1    1  26.0      0      0  30.0000        C
# 890          891         0       3    1  32.0      0      0   7.7500        Q
#
# [891 rows x 9 columns]

# %%
data['Age'].isna().sum()
# Out:
# np.int64(0)

# %%
data.isna().sum()
# Out:
# PassengerId    0
# Survived       0
# Pclass         0
# Sex            0
# Age            0
# SibSp          0
# Parch          0
# Fare           0
# Embarked       2
# dtype: int64

# %%
data['Embarked'].value_counts()
# Out:
# Embarked
# S    644
# C    168
# Q     77
# Name: count, dtype: int64

# %%
g = data.groupby('Survived')
g['Embarked'].value_counts() #grouping by multipulre columns
# Out:
# Survived  Embarked
# 0         S           427
#           C            75
#           Q            47
# 1         S           217
#           C            93
#           Q            30
# Name: count, dtype: int64

# %%
#filling the null values of Embarked with the s because the most values are in s

# %%
data['Embarked']=data['Embarked'].fillna(value='S')
data
# Out:
#      PassengerId  Survived  Pclass  Sex   Age  SibSp  Parch     Fare Embarked
# 0              1         0       3    1  22.0      1      0   7.2500        S
# 1              2         1       1    0  38.0      1      0  71.2833        C
# 2              3         1       3    0  26.0      0      0   7.9250        S
# 3              4         1       1    0  35.0      1      0  53.1000        S
# 4              5         0       3    1  35.0      0      0   8.0500        S
# ..           ...       ...     ...  ...   ...    ...    ...      ...      ...
# 886          887         0       2    1  27.0      0      0  13.0000        S
# 887          888         1       1    0  19.0      0      0  30.0000        S
# 888          889         0       3    0  28.0      1      2  23.4500        S
# 889          890         1       1    1  26.0      0      0  30.0000        C
# 890          891         0       3    1  32.0      0      0   7.7500        Q
#
# [891 rows x 9 columns]

# %%
#converting the Embarked in to catagorical data which are 0,1,2

# %%
from sklearn import preprocessing
label_encoder = preprocessing.LabelEncoder()
data['Embarked']= label_encoder.fit_transform(data['Embarked'])
data['Embarked'].value_counts()
data
# Out:
#      PassengerId  Survived  Pclass  Sex   Age  SibSp  Parch     Fare  Embarked
# 0              1         0       3    1  22.0      1      0   7.2500         2
# 1              2         1       1    0  38.0      1      0  71.2833         0
# 2              3         1       3    0  26.0      0      0   7.9250         2
# 3              4         1       1    0  35.0      1      0  53.1000         2
# 4              5         0       3    1  35.0      0      0   8.0500         2
# ..           ...       ...     ...  ...   ...    ...    ...      ...       ...
# 886          887         0       2    1  27.0      0      0  13.0000         2
# 887          888         1       1    0  19.0      0      0  30.0000         2
# 888          889         0       3    0  28.0      1      2  23.4500         2
# 889          890         1       1    1  26.0      0      0  30.0000         0
# 890          891         0       3    1  32.0      0      0   7.7500         1
#
# [891 rows x 9 columns]

# %%
#visulazing the data

# %%
data = data.dropna(subset=['Embarked', 'Survived'])
data
# Out:
#      PassengerId  Survived  Pclass  Sex   Age  SibSp  Parch     Fare  Embarked
# 0              1         0       3    1  22.0      1      0   7.2500         2
# 1              2         1       1    0  38.0      1      0  71.2833         0
# 2              3         1       3    0  26.0      0      0   7.9250         2
# 3              4         1       1    0  35.0      1      0  53.1000         2
# 4              5         0       3    1  35.0      0      0   8.0500         2
# ..           ...       ...     ...  ...   ...    ...    ...      ...       ...
# 886          887         0       2    1  27.0      0      0  13.0000         2
# 887          888         1       1    0  19.0      0      0  30.0000         2
# 888          889         0       3    0  28.0      1      2  23.4500         2
# 889          890         1       1    1  26.0      0      0  30.0000         0
# 890          891         0       3    1  32.0      0      0   7.7500         1
#
# [891 rows x 9 columns]

# %%
sns.countplot(x='Embarked', hue='Survived', data=data)
plt.show()

# %%
data.corr()

#Correlation measures how strongly two variables are related to each other.
#Values range from -1 to +1:
#+1 → Perfect positive correlation (both increase together)
#0 → No correlation
#-1 → Perfect negative correlation (one increases, the other decreases)
# Out:
#              PassengerId  Survived    Pclass       Sex       Age     SibSp  \
# PassengerId     1.000000 -0.005007 -0.035144  0.042939  0.034212 -0.057527
# Survived       -0.005007  1.000000 -0.338481 -0.543351 -0.064910 -0.035322
# Pclass         -0.035144 -0.338481  1.000000  0.131900 -0.339898  0.083081
# Sex             0.042939 -0.543351  0.131900  1.000000  0.081163 -0.114631
# Age             0.034212 -0.064910 -0.339898  0.081163  1.000000 -0.233296
# SibSp          -0.057527 -0.035322  0.083081 -0.114631 -0.233296  1.000000
# Parch          -0.001652  0.081629  0.018443 -0.245489 -0.172482  0.414838
# Fare            0.012658  0.257307 -0.549500 -0.182333  0.096688  0.159651
# Embarked        0.013128 -0.167675  0.162098  0.108262 -0.018754  0.068230
#
#                 Parch      Fare  Embarked
# PassengerId -0.001652  0.012658  0.013128
# Survived     0.081629  0.257307 -0.167675
# Pclass       0.018443 -0.549500  0.162098
# Sex         -0.245489 -0.182333  0.108262
# ...

# %%
data.plot(x='Survived',y=['SibSp', 'Parch'],kind="bar")
plt.show()

# %%
correlation = data.corr()
correlation['Survived'].sort_values(ascending=False)
# Out:
# Survived       1.000000
# Fare           0.257307
# Parch          0.081629
# PassengerId   -0.005007
# SibSp         -0.035322
# Age           -0.064910
# Embarked      -0.167675
# Pclass        -0.338481
# Sex           -0.543351
# Name: Survived, dtype: float64

# %%
sns.heatmap(data.corr())
# Out:
# <Axes: >

# %%
correlation['Fare'].sort_values(ascending=False)
correlation['Fare']
# Out:
# PassengerId    0.012658
# Survived       0.257307
# Pclass        -0.549500
# Sex           -0.182333
# Age            0.096688
# SibSp          0.159651
# Parch          0.216225
# Fare           1.000000
# Embarked      -0.224719
# Name: Fare, dtype: float64

# %%
data.head()
# Out:
#    PassengerId  Survived  Pclass  Sex   Age  SibSp  Parch     Fare  Embarked
# 0            1         0       3    1  22.0      1      0   7.2500         2
# 1            2         1       1    0  38.0      1      0  71.2833         0
# 2            3         1       3    0  26.0      0      0   7.9250         2
# 3            4         1       1    0  35.0      1      0  53.1000         2
# 4            5         0       3    1  35.0      0      0   8.0500         2

# %%
data['family']=data['SibSp']+data['Parch']+1
data=data.drop(['SibSp','Parch'],axis=1)
data=data.drop('PassengerId',axis=1)
data=data.drop('Embarked',axis=1)
data
# Out:
#      Survived  Pclass  Sex   Age     Fare  family
# 0           0       3    1  22.0   7.2500       2
# 1           1       1    0  38.0  71.2833       2
# 2           1       3    0  26.0   7.9250       1
# 3           1       1    0  35.0  53.1000       2
# 4           0       3    1  35.0   8.0500       1
# ..        ...     ...  ...   ...      ...     ...
# 886         0       2    1  27.0  13.0000       1
# 887         1       1    0  19.0  30.0000       1
# 888         0       3    0  28.0  23.4500       4
# 889         1       1    1  26.0  30.0000       1
# 890         0       3    1  32.0   7.7500       1
#
# [891 rows x 6 columns]

# %%
x=data.drop('Survived',axis=1).values
y=data['Survived'].values

# %%
from sklearn.linear_model import LogisticRegression
from skleran.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.3,random_state=100)

# %%
from sklearn.metrics import accuracy_score

# %%
lr = LogisticRegression()
lr.fit(x_train,y_train)# sending data to train 70%
irpred=lr.predict(x_test)

# %%
accuracy_score(y_test,irpred)
# Out:
# 0.7910447761194029

# %%
from sklearn.model_selection import GridSearchCV

#creating the hypermeter grid
c_sapce=np.logspace(-5, 8, 15)
param_grid={'C':c_sapce}

#instantiating the gridsearchcv object
logreg_cv = GridSearchCV(lr,param_grid,cv= 5)
logreg_cv.fit(x_train,y_train)

#printing the tuned parameters and score 
print("Tuned Logistic Regression Parameters:{}".format(logreg_cv.best_params_))
print("BEst Score is {}".format(logreg_cv.best_score_))
# Out:
# Tuned Logistic Regression Parameters:{'C': np.float64(31.622776601683793)}
# BEst Score is 0.8042193548387097
